# %%
import pandas as pd

# %%
l = [x**2 for x in range(1,10)]
print(l)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
s = pd.Series(l,name = 'Squares')
s
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# 4    25
# 5    36
# 6    49
# 7    64
# 8    81
# Name: Squares, dtype: int64

# %%
s.ndim
# Out:
# 1

# %%
s.size
# Out:
# 9

# %%
s.shape
# Out:
# (9,)

# %%
s.dtype
# Out:
# dtype('int64')

# %%
dic={'Eno':[100,101,102,103],'Ename':['Ram','Shyam','Rohit','Manav'],'Esal':[100.00,100.00,100.00,100.00]}
dic
# Out:
# {'Eno': [100, 101, 102, 103],
#  'Ename': ['Ram', 'Shyam', 'Rohit', 'Manav'],
#  'Esal': [100.0, 100.0, 100.0, 100.0]}

# %%
df = pd.DataFrame(dic,index=['r1','r2','r3','r4'])
df
# Out:
#     Eno  Ename   Esal
# r1  100    Ram  100.0
# r2  101  Shyam  100.0
# r3  102  Rohit  100.0
# r4  103  Manav  100.0

# %%
df[['Eno','Ename']]
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
c = df['Eno']
type(c)
# Out:
# pandas.core.series.Series

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 12

# %%
df.shape
# Out:
# (4, 3)

# %%
df.dtypes
# Out:
# Eno        int64
# Ename     object
# Esal     float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
# Eno      4 non-null int64
# Ename    4 non-null object
# Esal     4 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 176.0+ bytes

# %%
df.items
# Out:
# <bound method DataFrame.iteritems of    Eno  Ename   Esal
# 0  100    Ram  100.0
# 1  101  Shyam  100.0
# 2  102  Rohit  100.0
# 3  103  Manav  100.0>

# %%
df.describe()
# Out:
#               Eno   Esal
# count    4.000000    4.0
# mean   101.500000  100.0
# std      1.290994    0.0
# min    100.000000  100.0
# 25%    100.750000  100.0
# 50%    101.500000  100.0
# 75%    102.250000  100.0
# max    103.000000  100.0

# %%
df['Esal'].min()
# Out:
# 100.0

# %%
df['Esal'].mean()
# Out:
# 100.0

# %%
df['Esal'].max()
# Out:
# 100.0

# %%
df.loc['r1':'r2','Ename':'Esal']
# Out:
#     Ename   Esal
# r1    Ram  100.0
# r2  Shyam  100.0

# %%
df.iloc[0:2,1:2]
# Out:
#     Ename
# r1    Ram
# r2  Shyam

# %%
iris = pd.read_csv('iris.csv')
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# 6             4.6          3.4           1.4          0.3     Setosa
# 7             5.0          3.4           1.5          0.2     Setosa
# 8             4.4          2.9           1.4          0.2     Setosa
# 9             4.9          3.1           1.5          0.1     Setosa
# 10            5.4          3.7           1.5          0.2     Setosa
# 11            4.8          3.4           1.6          0.2     Setosa
# 12            4.8          3.0           1.4          0.1     Setosa
# ...

# %%
iris.info
# Out:
# <bound method DataFrame.info of      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# 6             4.6          3.4           1.4          0.3     Setosa
# 7             5.0          3.4           1.5          0.2     Setosa
# 8             4.4          2.9           1.4          0.2     Setosa
# 9             4.9          3.1           1.5          0.1     Setosa
# 10            5.4          3.7           1.5          0.2     Setosa
# 11            4.8          3.4           1.6          0.2     Setosa
# ...

# %%
iris.head(10)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa
# 8           4.4          2.9           1.4          0.2  Setosa
# 9           4.9          3.1           1.5          0.1  Setosa

# %%
iris.tail()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
iris['sepal.length']>5
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10      True
# 11     False
# 12     False
# 13     False
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22     False
# 23      True
# 24     False
# 25     False
# 26     False
# 27      True
# 28      True
# 29     False
#        ...
# 120     True
# 121     True
# 122     True
# 123     True
# 124     True
# 125     True
# 126     True
# 127     True
# 128     True
# 129     True
# 130     True
# 131     True
# 132     True
# 133     True
# 134     True
# 135     True
# 136     True
# 137     True
# 138     True
# 139     True
# 140     True
# 141     True
# 142     True
# 143     True
# 144     True
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: sepal.length, Length: 150, dtype: bool

# %%
iris[iris['sepal.length']>5]['sepal.length']=1
iris
# Out:
# /home/anaconda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# 6             4.6          3.4           1.4          0.3     Setosa
# ...

# %%
iris = pd.read_csv('iris.csv',skiprows=3,names=['a','b','c','d','e'])
iris
# Out:
#        a    b    c    d          e
# 0    5.1  3.5  1.4  0.2     Setosa
# 1    4.9  3.0  1.4  0.2     Setosa
# 2    4.7  3.2  1.3  0.2     Setosa
# 3    4.6  3.1  1.5  0.2     Setosa
# 4    5.0  3.6  1.4  0.2     Setosa
# 5    5.4  3.9  1.7  0.4     Setosa
# 6    4.6  3.4  1.4  0.3     Setosa
# 7    5.0  3.4  1.5  0.2     Setosa
# 8    4.4  2.9  1.4  0.2     Setosa
# 9    4.9  3.1  1.5  0.1     Setosa
# 10   5.4  3.7  1.5  0.2     Setosa
# 11   4.8  3.4  1.6  0.2     Setosa
# 12   4.8  3.0  1.4  0.1     Setosa
# 13   4.3  3.0  1.1  0.1     Setosa
# 14   5.8  4.0  1.2  0.2     Setosa
# 15   5.7  4.4  1.5  0.4     Setosa
# 16   5.4  3.9  1.3  0.4     Setosa
# 17   5.1  3.5  1.4  0.3     Setosa
# 18   5.7  3.8  1.7  0.3     Setosa
# 19   5.1  3.8  1.5  0.3     Setosa
# 20   5.4  3.4  1.7  0.2     Setosa
# 21   5.1  3.7  1.5  0.4     Setosa
# 22   4.6  3.6  1.0  0.2     Setosa
# 23   5.1  3.3  1.7  0.5     Setosa
# 24   4.8  3.4  1.9  0.2     Setosa
# 25   5.0  3.0  1.6  0.2     Setosa
# ...
